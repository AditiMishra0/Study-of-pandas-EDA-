# %% [markdown]
# #Experiment 9 - Study of Pandas
# ###Aditi Mishra
# ###25070123175
# ###ENTC A2

# %%
import pandas as pd

s = pd.Series([1, 2, 3, 4, 5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#Create Dataframe

data = {

        "Name":["A","B","C","D","E"],
        "Marks":[90,95,98,80,76]
}
df = pd.DataFrame(data)
df
# Out:
#   Name  Marks
# 0    A     90
# 1    B     95
# 2    C     98
# 3    D     80
# 4    E     76

# %%
#Find the structure of the data frame

df.shape
# Out:
# (5, 2)

# %%
#Find dimension of data frame

df.ndim
# Out:
# 2

# %%
#Find size of data frame

df.size
# Out:
# 10

# %%
#Display column names

df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
#Check data types of each column

df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
#Access individual column

df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# Name: Name, dtype: object

# %%
#Access specific row

df.loc[2]
# Out:
# Name      C
# Marks    98
# Name: 2, dtype: object

# %%
#Add a new column

df["Ranking"] = ["Third", "Second","First","Fourth","Fifth"]
df
# Out:
#   Name  Marks Ranking
# 0    A     90   Third
# 1    B     95  Second
# 2    C     98   First
# 3    D     85  Fourth
# 4    E     76   Fifth

# %%
#Update data in dataframe

#Change marks of student D to 85

df.loc[3,"Marks"] = 85
df
# Out:
#   Name  Marks Ranking
# 0    A     90   Third
# 1    B     95  Second
# 2    C     98   First
# 3    D     85  Fourth
# 4    E     76   Fifth

# %%
#Delete a column

df.drop("Ranking",axis=1, inplace = True)
df
# Out:
#   Name  Marks
# 0    A     90
# 1    B     95
# 2    C     98
# 3    D     85
# 4    E     76

# %% [markdown]
# ###Basic statistical ananlysis

# %%
#mean

mean1 = df["Marks"].mean()
mean1
# Out:
# np.float64(88.8)

# %%
#minimum marks

min1 = df["Marks"].min()
min1
# Out:
# 76

# %%
#maximum marks

max1 = df["Marks"].max()
max1
# Out:
# 98

# %% [markdown]
# ###Apply conditions (Filtering)

# %%
#Display students scoring more than 80

df[df["Marks"]>80]
# Out:
#   Name  Marks
# 0    A     90
# 1    B     95
# 2    C     98
# 3    D     85
